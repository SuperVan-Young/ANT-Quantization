# %%
area_olive = 79.57
area_oltron = 73.5
area_oltron_large = 155.23

# %%
total_area_olive = 64 * 64 * area_olive
total_area_olive
# Out:
# 325918.72

# %%
total_area_oltron = 64 * 60 * area_oltron + 64 * 4 * area_oltron_large
total_area_oltron
# Out:
# 321978.88

# %%
total_modified_olive_area = 64 * 32 * area_oltron_large
total_modified_olive_area
# Out:
# 317911.04
